# %%
from pathlib import Path
import os
from dotenv import load_dotenv

# Load .env from repo root (next to this notebook)
dotenv_path = Path("..") / ".env"
loaded = load_dotenv(dotenv_path)
print(f".env found: {dotenv_path.resolve().exists()}  loaded: {loaded}")

def env_str(key, default=None, required=False):
    val = os.getenv(key, default)
    if required and (val is None or str(val).strip() == ""):
        raise ValueError(f"Missing required env var: {key}")
    return val

def env_int(key, default=None, required=False):
    v = env_str(key, default, required)
    return int(v) if v is not None else None

def env_float(key, default=None, required=False):
    v = env_str(key, default, required)
    return float(v) if v is not None else None
# Out:
# .env found: True  loaded: True

# %%
from datetime import datetime
import json, hashlib
import pandas as pd
from google.maps import routeoptimization_v1 as ro

# Pull config from env
PROJECT       = env_str("GOOGLE_CLOUD_PROJECT", required=True)
PARENT        = f"projects/{PROJECT}"

# If you provided a service account JSON, ADC will use it automatically
gac = env_str("GOOGLE_APPLICATION_CREDENTIALS", default=None)
if gac:
    p = Path(gac)
    print(f"GOOGLE_APPLICATION_CREDENTIALS set -> exists: {p.exists()}  path: {p}")

DEPOT_LAT=10.2509284
DEPOT_LNG=105.978708
FLEET_SIZE    = env_int("FLEET_SIZE", 10)

GLOBAL_START  = env_str("GLOBAL_START", "2025-10-28T01:00:00Z")
GLOBAL_END    = env_str("GLOBAL_END",   "2025-10-28T15:00:00Z")

DELIVERIES_CSV = Path(env_str("DELIVERIES_CSV", "data/deliveries.csv"))

print("Config loaded from env:")
print("  PARENT:", PARENT)
print("  DEPOT:", (DEPOT_LAT, DEPOT_LNG))
print("  FLEET_SIZE:", FLEET_SIZE)
print("  TIME WINDOW:", GLOBAL_START, "→", GLOBAL_END)
print("  FILE:", DELIVERIES_CSV.resolve())
# Out:
# Config loaded from env:
#   PARENT: projects/hidden-terrain-476501-e6
#   DEPOT: (10.2509284, 105.978708)
#   FLEET_SIZE: 10
#   TIME WINDOW: 2025-10-28T01:00:00Z → 2025-10-28T15:00:00Z
#   FILE: /Users/huynhtai/Desktop/4. projects/VHoang/project/data/deliveries.csv

# %%
def parse_latlng_str(val: str):
    parts = [p.strip() for p in str(val).split(",")]
    if len(parts) < 2:
        raise ValueError(f"Bad coordinates string: {val}")
    return float(parts[0]), float(parts[1])

def latlng(lat, lng):
    return {"latitude": float(lat), "longitude": float(lng)}

def gmaps_url(origin, waypoints, destination):
    def fmt(ll): return f"{ll[0]},{ll[1]}"
    parts = [
        "api=1",
        f"origin={fmt(origin)}",
        f"destination={fmt(destination)}",
    ]
    if waypoints:
        parts.append("waypoints=" + "|".join(fmt(w) for w in waypoints))
    return "https://www.google.com/maps/dir/?" + "&".join(parts)

print("Helpers ready: parse_latlng_str, latlng, gmaps_url")
# Out:
# Helpers ready: parse_latlng_str, latlng, gmaps_url

# %%
assert DELIVERIES_CSV.exists(), f"Missing file: {DELIVERIES_CSV}"
df = pd.read_csv(DELIVERIES_CSV)
df.columns = [c.strip().lower() for c in df.columns]

required_cols = {"label", "coordinates"}
missing = required_cols - set(df.columns)
if missing:
    raise ValueError(f"deliveries.csv missing columns: {missing}")

print(f"Loaded deliveries: {len(df)} rows")
print(df.head(10))

# Build label -> (lat,lng)
label_to_ll = {}
bad_rows = []
for idx, row in df.iterrows():
    try:
        label = str(row["label"]).strip()
        dlat, dlng = parse_latlng_str(row["coordinates"])
        label_to_ll[label] = (dlat, dlng)
    except Exception as e:
        bad_rows.append((idx, str(e)))

if bad_rows:
    print("Warning: bad rows encountered:")
    for idx, msg in bad_rows[:10]:
        print("  row", idx, "->", msg)
else:
    print("All delivery coordinates parsed successfully.")

print("First 5 label→coords:", list(label_to_ll.items())[:5])
# Out:
# Loaded deliveries: 97 rows
#                                                label             coordinates
# 0  19 Nguyen Tat Thanh, Phu Thuy, Phan Thiet City...  10.9287267,108.1103265
# 1  9 Nguyễn Đình Chiểu Street, Ward 1, Bến Tre Ci...  10.3493245,107.0759918
# 2  84 Đường 30/4, Ward 2, Bạc Liêu City, Bạc Liêu...  10.5253636,107.1854734
# 3  2 Cong Xa Paris, Ben Nghe Ward, District 1, Ho...  10.7800898,106.6995646
# 4  16 Phan Chu Trinh Street, Ward 1, Trà Vinh Cit...  10.9320161,106.8654049
# 5  9A Đường 22 Tháng 12, Thuận Giao Ward, Thuận A...   10.924871,107.2413524
# 6  7 Nguyễn Văn Cừ Street, Mỹ Thới Ward, Long Xuy...   11.001337,106.6671784
# 7  45 Nguyễn Trãi Street, Ward 4, Vị Thanh City, ...   10.9463042,106.680124
# 8  186 30/4 Street, Ward 3, Tay Ninh City, Tay Ni...  11.3351554,106.1098854
# 9  No. 1, National Highway 1, Ward 2, Tan An City...   10.5651354,106.420883
# All delivery coordinates parsed successfully.
# First 5 label→coords: [('19 Nguyen Tat Thanh, Phu Thuy, Phan Thiet City, Binh Thuan, Vietnam', (10.9287267, 108.1103265)), ('9 Nguyễn Đình Chiểu Street, Ward 1, Bến Tre City, Bến Tre Province, Vietnam', (10.3493245, 107.0759918)), ('84 Đường 30/4, Ward 2, Bạc Liêu City, Bạc Liêu Province, Vietnam', (10.743141234670162, 106.63003946176038)), ('2 Cong Xa Paris, Ben Nghe Ward, District 1, Ho Chi Minh City, Vietnam', (10.7800898, 106.6995646)), ('16 Phan Chu Trinh Street, Ward 1, Trà Vinh City, Trà Vinh Province, Vietnam', (10.9320161, 106.8654049))]

# %%
shipments = []
for label, (dlat, dlng) in label_to_ll.items():
    shipments.append({
        "label": label,
        "deliveries": [
            { "arrival_location": latlng(dlat, dlng) }
        ]
    })

print(f"Shipments built: {len(shipments)}")
print("Preview of first 3 shipments:")
print(json.dumps(shipments[:3], indent=2))
# Out:
# Shipments built: 96
# Preview of first 3 shipments:
# [
#   {
#     "label": "19 Nguyen Tat Thanh, Phu Thuy, Phan Thiet City, Binh Thuan, Vietnam",
#     "deliveries": [
#       {
#         "arrival_location": {
#           "latitude": 10.9287267,
#           "longitude": 108.1103265
#         }
#       }
#     ]
#   },
#   {
#     "label": "9 Nguy\u1ec5n \u0110\u00ecnh Chi\u1ec3u Street, Ward 1, B\u1ebfn Tre City, B\u1ebfn Tre Province, Vietnam",
#     "deliveries": [
#       {
#         "arrival_location": {
#           "latitude": 10.3493245,
#           "longitude": 107.0759918
#         }
#       }
#     ]
#   },
#   {
#     "label": "84 \u0110\u01b0\u1eddng 30/4, Ward 2, B\u1ea1c Li\u00eau City, B\u1ea1c Li\u00eau Province, Vietnam",
#     "deliveries": [
#       {
#         "arrival_location": {
#           "latitude": 10.743141234670162,
#           "longitude": 106.63003946176038
#         }
#       }
#     ]
#   }
# ]

# %%
vehicles = []
for i in range(1, FLEET_SIZE + 1):
    vehicles.append({
        "label": f"V{i}",
        "start_location": latlng(DEPOT_LAT, DEPOT_LNG),
        "end_location":   latlng(DEPOT_LAT, DEPOT_LNG)
    })

print(f"Vehicles built: {len(vehicles)}")
print("Vehicle labels:", [v["label"] for v in vehicles])
print("First vehicle preview:")
print(json.dumps(vehicles[0], indent=2))
# Out:
# Vehicles built: 10
# Vehicle labels: ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10']
# First vehicle preview:
# {
#   "label": "V1",
#   "start_location": {
#     "latitude": 10.2509284,
#     "longitude": 105.978708
#   },
#   "end_location": {
#     "latitude": 10.2509284,
#     "longitude": 105.978708
#   }
# }

# %%
model = {
    "shipments": shipments,
    "vehicles": vehicles,
    "global_start_time": GLOBAL_START,
    "global_end_time": GLOBAL_END
}

print("Model summary:")
print("  shipments:", len(model["shipments"]))
print("  vehicles:", len(model["vehicles"]))
print("  window:", model["global_start_time"], "→", model["global_end_time"])
print("Model preview (first shipment, first vehicle):")
print(json.dumps({"shipment": model["shipments"][0], "vehicle": model["vehicles"][0]}, indent=2))
# Out:
# Model summary:
#   shipments: 96
#   vehicles: 10
#   window: 2025-10-28T01:00:00Z → 2025-10-28T15:00:00Z
# Model preview (first shipment, first vehicle):
# {
#   "shipment": {
#     "label": "19 Nguyen Tat Thanh, Phu Thuy, Phan Thiet City, Binh Thuan, Vietnam",
#     "deliveries": [
#       {
#         "arrival_location": {
#           "latitude": 10.9287267,
#           "longitude": 108.1103265
#         }
#       }
#     ]
#   },
#   "vehicle": {
#     "label": "V1",
#     "start_location": {
#       "latitude": 10.2509284,
#       "longitude": 105.978708
#     },
#     "end_location": {
#       "latitude": 10.2509284,
#       "longitude": 105.978708
#     }
#   }
# }

# %%
print(json.dumps(model, indent=2))
# Out:
# {
#   "shipments": [
#     {
#       "label": "19 Nguyen Tat Thanh, Phu Thuy, Phan Thiet City, Binh Thuan, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.9287267,
#             "longitude": 108.1103265
#           }
#         }
#       ]
#     },
#     {
#       "label": "9 Nguy\u1ec5n \u0110\u00ecnh Chi\u1ec3u Street, Ward 1, B\u1ebfn Tre City, B\u1ebfn Tre Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.3493245,
#             "longitude": 107.0759918
#           }
#         }
#       ]
#     },
#     {
#       "label": "84 \u0110\u01b0\u1eddng 30/4, Ward 2, B\u1ea1c Li\u00eau City, B\u1ea1c Li\u00eau Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.743141234670162,
#             "longitude": 106.63003946176038
#           }
#         }
#       ]
#     },
#     {
#       "label": "2 Cong Xa Paris, Ben Nghe Ward, District 1, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.7800898,
#             "longitude": 106.6995646
#           }
#         }
#       ]
#     },
#     {
#       "label": "16 Phan Chu Trinh Street, Ward 1, Tr\u00e0 Vinh City, Tr\u00e0 Vinh Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.9320161,
#             "longitude": 106.8654049
#           }
#         }
#       ]
#     },
#     {
#       "label": "9A \u0110\u01b0\u1eddng 22 Th\u00e1ng 12, Thu\u1eadn Giao Ward, Thu\u1eadn An City, B\u00ecnh D\u01b0\u01a1ng Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.924871,
#             "longitude": 107.2413524
#           }
#         }
#       ]
#     },
#     {
#       "label": "7 Nguy\u1ec5n V\u0103n C\u1eeb Street, M\u1ef9 Th\u1edbi Ward, Long Xuy\u00ean City, An Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.001337,
#             "longitude": 106.6671784
#           }
#         }
#       ]
#     },
#     {
#       "label": "45 Nguy\u1ec5n Tr\u00e3i Street, Ward 4, V\u1ecb Thanh City, H\u1eadu Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.9463042,
#             "longitude": 106.680124
#           }
#         }
#       ]
#     },
#     {
#       "label": "186 30/4 Street, Ward 3, Tay Ninh City, Tay Ninh, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.3351554,
#             "longitude": 106.1098854
#           }
#         }
#       ]
#     },
#     {
#       "label": "No. 1, National Highway 1, Ward 2, Tan An City, Long An, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.5651354,
#             "longitude": 106.420883
#           }
#         }
#       ]
#     },
#     {
#       "label": "No. 58, 30/4 Street, Ward 3, My Tho City, Tien Giang, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.3765284,
#             "longitude": 106.3438891
#           }
#         }
#       ]
#     },
#     {
#       "label": "3/1 Dong Khoi Street, Ward 3, Ben Tre City, Ben Tre, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.2451404,
#             "longitude": 106.35533
#           }
#         }
#       ]
#     },
#     {
#       "label": "Hung Vuong Street, Ward 4, Tra Vinh City, Tra Vinh, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 9.936612,
#             "longitude": 106.3457042
#           }
#         }
#       ]
#     },
#     {
#       "label": "26 Ba Th\u00e1ng Hai Street, Ward 1, V\u0129nh Long City, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.246310335473204,
#             "longitude": 105.93858434280287
#           }
#         }
#       ]
#     },
#     {
#       "label": "Khu d\u00e2n c\u01b0 H\u00f9ng V\u01b0\u01a1ng I, Ph\u00fa Th\u1ee7y Ward, Phan Thi\u1ebft City, B\u00ecnh Thu\u1eadn Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.247025916127395,
#             "longitude": 105.93858474386575
#           }
#         }
#       ]
#     },
#     {
#       "label": "1231 Qu\u1ed1c l\u1ed9 1A, B\u00ecnh Tr\u1ecb \u0110\u00f4ng B Ward, B\u00ecnh T\u00e2n District, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.24814972360808,
#             "longitude": 105.9391854507987
#           }
#         }
#       ]
#     },
#     {
#       "label": "35-37 Cach Mang Thang Tam Street, Cai Khe Ward, Can Tho City, Can Tho, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 9.41747528429018,
#             "longitude": 105.59317885406331
#           }
#         }
#       ]
#     },
#     {
#       "label": "Hung Vuong I Residential Area, Phu Thuy Ward, Phan Thiet City, Binh Thuan Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 9.418037372033817,
#             "longitude": 105.6005661954456
#           }
#         }
#       ]
#     },
#     {
#       "label": "Nguyen Ai Quoc Street, Quang Vinh Ward, Bien Hoa City, Dong Nai Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 9.402699564889831,
#             "longitude": 105.48577491215896
#           }
#         }
#       ]
#     },
#     {
#       "label": "Binh Phu Ward, District 6, Ho Chi Minh City, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 9.388217284138706,
#             "longitude": 105.46610543102882
#           }
#         }
#       ]
#     },
#     {
#       "label": "No.01 Binh Duong Boulevard, Thuan Giao Ward, Thu Dau Mot City, Binh Duong Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 9.737800812160588,
#             "longitude": 104.98777490242773
#           }
#         }
#       ]
#     },
#     {
#       "label": "366 Phan Van Tri Street, Ward 5, Go Vap District, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 9.726043218624302,
#             "longitude": 104.98088408672194
#           }
#         }
#       ]
#     },
#     {
#       "label": "128 Tran Quang Khai Street, Tan Dinh Ward, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 9.374541692375605,
#             "longitude": 104.99408597646179
#           }
#         }
#       ]
#     },
#     {
#       "label": "772 Dien Bien Phu Street, Ward 22, Binh Thanh District, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 9.393348751263346,
#             "longitude": 104.97641522453826
#           }
#         }
#       ]
#     },
#     {
#       "label": "Cantavil Complex (B1 Cantavil An Phu), An Phu Ward, Thu Duc City, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 8.971049441216051,
#             "longitude": 105.01406211914232
#           }
#         }
#       ]
#     },
#     {
#       "label": "Vinh Long Market (Ch\u1ee3 V\u0129nh Long), 19 Thang 8 Street, Ward 1, Vinh Long City, Vinh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 8.941003414548625,
#             "longitude": 105.01527170244819
#           }
#         }
#       ]
#     },
#     {
#       "label": "Cai Rang Floating Market / Cai Rang (Ch\u1ee3 n\u1ed5i C\u00e1i R\u0103ng), Cai Rang District, Can Tho City, Can Tho, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 8.76164908277841,
#             "longitude": 104.997805833565
#           }
#         }
#       ]
#     },
#     {
#       "label": "Tan An Wholesale Market (Ch\u1ee3 T\u00e2n An), Cai Rang District, Can Tho City, Can Tho, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 8.758145889281952,
#             "longitude": 104.98812164444232
#           }
#         }
#       ]
#     },
#     {
#       "label": "An Khanh New Urban Area, An Phu Ward, Thu Duc City, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 8.609909369694835,
#             "longitude": 104.90373878488529
#           }
#         }
#       ]
#     },
#     {
#       "label": "10 Mai Chi Tho Street, Thu Thiem, Thu Duc City, Ho Chi Minh City, Vietnam (Emart / Sala area store)",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 8.59106672491821,
#             "longitude": 104.83826110291905
#           }
#         }
#       ]
#     },
#     {
#       "label": "1 L\u00ea Du\u1ea9n Street, Ward 1, Phan Thi\u1ebft City, B\u00ecnh Thu\u1eadn, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.84182460906173,
#             "longitude": 106.70162045292557
#           }
#         }
#       ]
#     },
#     {
#       "label": "123 Qu\u1ed1c l\u1ed9 1A, B\u00ecnh Tr\u1ecb \u0110\u00f4ng B Ward, B\u00ecnh T\u00e2n District, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.818323837043087,
#             "longitude": 106.67880503389469
#           }
#         }
#       ]
#     },
#     {
#       "label": "22-24 Nguy\u1ec5n Hu\u1ec7 Street, Ward 1, C\u1ea7n Th\u01a1 City, C\u1ea7n Th\u01a1, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.536206008977883,
#             "longitude": 106.95330841416676
#           }
#         }
#       ]
#     },
#     {
#       "label": "Lot B, An Ph\u00fa - An Kh\u00e1nh New Urban Area, An Ph\u00fa Ward, Thu \u0110uc City, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.520833247660347,
#             "longitude": 106.90006772092273
#           }
#         }
#       ]
#     },
#     {
#       "label": "10 Mai Ch\u00ed Th\u1ecd Street, Thu Thiem Ward, Thu Duc City, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.436676159507831,
#             "longitude": 106.04706494326466
#           }
#         }
#       ]
#     },
#     {
#       "label": "772 \u0110i\u1ec7n Bi\u00ean Ph\u1ee7 Street, Ward 22, B\u00ecnh Th\u1ea1nh District, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.35381565552002,
#             "longitude": 106.07392126140543
#           }
#         }
#       ]
#     },
#     {
#       "label": "01 Binh Duong Boulevard, Thu\u1eadn Giao Ward, Thu Dau Mot City, Binh Duong Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.553094507466545,
#             "longitude": 107.4633527114996
#           }
#         }
#       ]
#     },
#     {
#       "label": "128 Tr\u1ea7n Quang Kh\u1ea3i Street, T\u00e2n \u0110\u1ecbnh Ward, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.502570051482715,
#             "longitude": 107.51013135784346
#           }
#         }
#       ]
#     },
#     {
#       "label": "5 Nguy\u1ec5n T\u1ea5t Th\u00e0nh Street, Ph\u00fa Th\u1ee7y Ward, Phan Thi\u1ebft City, B\u00ecnh Thu\u1eadn, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.511685706937962,
#             "longitude": 106.60191422617284
#           }
#         }
#       ]
#     },
#     {
#       "label": "19 Th\u00e1ng 8 Street, Ward 1, Vinh Long City, Vinh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.47486093819702,
#             "longitude": 106.60003043145726
#           }
#         }
#       ]
#     },
#     {
#       "label": "Ch\u1ee3 C\u00e1i R\u0103ng, Cai R\u0103ng District, Can Tho City, Can Tho, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.36956871136917,
#             "longitude": 106.49905240248872
#           }
#         }
#       ]
#     },
#     {
#       "label": "45 Nguy\u1ec5n V\u0103n Linh Street, An H\u00f2a Ward, R\u1ea1ch Gi\u00e1 City, Ki\u00ean Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.355977993596188,
#             "longitude": 106.48283564545497
#           }
#         }
#       ]
#     },
#     {
#       "label": "66 Tr\u01b0ng N\u1eef V\u01b0\u01a1ng Street, Ward 3, B\u1ebfn Tre City, B\u1ebfn Tre Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.414010765404969,
#             "longitude": 106.41212577974605
#           }
#         }
#       ]
#     },
#     {
#       "label": "2A Nguy\u1ec5n \u0110\u00ecnh Chi\u1ec3u Street, Ph\u01b0\u1edbc Hi\u1ec7p Ward, B\u00e0 R\u1ecba City, B\u00e0 R\u1ecba\u2013V\u0169ng T\u00e0u Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.357721984471517,
#             "longitude": 105.5140131222994
#           }
#         }
#       ]
#     },
#     {
#       "label": "18 Tr\u1ea7n Ph\u00fa Street, Ward 5, M\u1ef9 Tho City, Ti\u1ec1n Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.347062527288568,
#             "longitude": 105.49148062625179
#           }
#         }
#       ]
#     },
#     {
#       "label": "9 Nguy\u1ec5n Hu\u1ec7 Street, Ward 2, Tr\u00e0 Vinh City, Tr\u00e0 Vinh Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.455934299048067,
#             "longitude": 105.34307392794999
#           }
#         }
#       ]
#     },
#     {
#       "label": "101 Hai B\u00e0 Tr\u01b0ng Street, Ward 2, S\u00f3c Tr\u0103ng City, S\u00f3c Tr\u0103ng Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.463966714458348,
#             "longitude": 104.93084288031928
#           }
#         }
#       ]
#     },
#     {
#       "label": "77 Nguy\u1ec5n V\u0103n C\u1eeb Street, Ward 1, C\u00e0 Mau City, C\u00e0 Mau Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.601284857611843,
#             "longitude": 106.61621164217863
#           }
#         }
#       ]
#     },
#     {
#       "label": "28 L\u00ea L\u1ee3i Street, Ward 1, B\u1ea1c Li\u00eau City, B\u1ea1c Li\u00eau Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.595667190715176,
#             "longitude": 106.60996983767556
#           }
#         }
#       ]
#     },
#     {
#       "label": "60 H\u00f9ng V\u01b0\u01a1ng Street, Ward 2, Long Xuy\u00ean City, An Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.44379681436063,
#             "longitude": 106.17347383366526
#           }
#         }
#       ]
#     },
#     {
#       "label": "15 Tr\u1ea7n H\u01b0ng \u0110\u1ea1o Street, Ward 3, V\u0129nh Long City, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.930113757038242,
#             "longitude": 107.24123033005378
#           }
#         }
#       ]
#     },
#     {
#       "label": "MM Mega Market An Ph\u00fa \u2014 B1 Cantavil An Ph\u00fa, An Ph\u00fa Ward, Thu Duc City, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.595616795466086,
#             "longitude": 107.19589129513493
#           }
#         }
#       ]
#     },
#     {
#       "label": "Metro Cash & Carry Bi\u00ean H\u00f2a \u2014 Nguy\u1ec5n \u00c1i Qu\u1ed1c area, Quang Vinh Ward, Bi\u00ean H\u00f2a City, \u0110\u1ed3ng Nai Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.817185474371641,
#             "longitude": 106.2713274249572
#           }
#         }
#       ]
#     },
#     {
#       "label": "AEON Mall Phu My Hung \u2014 30A Nguyen Luong Bang Street, Tan Phu Ward, District 7, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.826396405971355,
#             "longitude": 107.88205447936679
#           }
#         }
#       ]
#     },
#     {
#       "label": "WinMart+ / Bach Hoa Xanh cluster \u2014 1A Nguy\u1ec5n Tr\u00e3i Street, Ward 2, V\u0129nh Long City, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.497931310093557,
#             "longitude": 107.380419751467
#           }
#         }
#       ]
#     },
#     {
#       "label": "Ch\u1ee3 T\u00e2n An (wholesale market), T\u00e2n An Town, T\u00e2n An District, Long An Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.462247106227197,
#             "longitude": 107.34444987239767
#           }
#         }
#       ]
#     },
#     {
#       "label": "54A \u0110inh Ti\u00ean Ho\u00e0ng Street, Ward 8, V\u0129nh Long City, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.668866930027399,
#             "longitude": 107.40310361116963
#           }
#         }
#       ]
#     },
#     {
#       "label": "608 Kh\u00f3m 1, C\u00e1i V\u1ed3n Town, B\u00ecnh Minh Town, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.68456366726326,
#             "longitude": 107.39475546390835
#           }
#         }
#       ]
#     },
#     {
#       "label": "151 V\u00f5 Th\u1ecb S\u00e1u Street, Th\u1ecb Tr\u1ea5n Long \u0110i\u1ec1n, Huy\u1ec7n Long \u0110i\u1ec1n, B\u00e0 R\u1ecba\u2013V\u0169ng T\u00e0u Province, Vietnam.",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.098237830681569,
#             "longitude": 107.91723384372865
#           }
#         }
#       ]
#     },
#     {
#       "label": "1A Nguy\u1ec5n T\u1ea5t Th\u00e0nh Street, Ph\u01b0\u1eddng B\u00ecnh H\u01b0ng, Phan Thi\u1ebft City, B\u00ecnh Thu\u1eadn Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.030606493906447,
#             "longitude": 107.8666848587414
#           }
#         }
#       ]
#     },
#     {
#       "label": "\u0110\u01b0\u1eddng T\u1ec9nh 906, Hi\u1ebfu Thu\u1eadn Commune, V\u0169ng Li\u00eam District, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.960337794314972,
#             "longitude": 107.78857892616706
#           }
#         }
#       ]
#     },
#     {
#       "label": "\u0110T 907, Trung An Commune, V\u0169ng Li\u00eam District, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.927086185083015,
#             "longitude": 107.67091648232422
#           }
#         }
#       ]
#     },
#     {
#       "label": "B\u00ecnh Ph\u01b0\u1edbc Commune, Mang Th\u00edt District, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.899346420249902,
#             "longitude": 107.67070246000341
#           }
#         }
#       ]
#     },
#     {
#       "label": "An Hi\u1ec7p Commune, Long H\u1ed3 District, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.945967849331062,
#             "longitude": 107.37194619351925
#           }
#         }
#       ]
#     },
#     {
#       "label": "105 Ph\u1ea1m H\u1eefu L\u1ea7u Street, Tr\u00e0 Vinh City, Tr\u00e0 Vinh Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.70441206569353,
#             "longitude": 106.9427495710599
#           }
#         }
#       ]
#     },
#     {
#       "label": "264 Nguy\u1ec5n Hu\u1ec7 Street, Khu Ph\u1ed1 2, Th\u1ecb Tr\u1ea5n T\u00e2n Minh, Huy\u1ec7n H\u00e0m T\u00e2n, B\u00ecnh Thu\u1eadn Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.760051713402298,
#             "longitude": 106.9266247444845
#           }
#         }
#       ]
#     },
#     {
#       "label": "12 L\u00ea L\u1ee3i Street, Ward 1, B\u1ebfn Tre City, B\u1ebfn Tre Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.807820408243742,
#             "longitude": 106.86913289382157
#           }
#         }
#       ]
#     },
#     {
#       "label": "8 Nguy\u1ec5n Hu\u1ec7 Street, Ward 2, Tr\u00e0 Vinh City, Tr\u00e0 Vinh Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.92813147435151,
#             "longitude": 106.87735190240946
#           }
#         }
#       ]
#     },
#     {
#       "label": "54 Nguy\u1ec5n V\u0103n C\u1eeb Street, Ward 1, C\u00e0 Mau City, C\u00e0 Mau Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.095812840181841,
#             "longitude": 106.7351984049071
#           }
#         }
#       ]
#     },
#     {
#       "label": "88 Nguy\u1ec5n C\u00f4ng Tr\u1ee9 Street, Ward 8, V\u0129nh Long City, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 11.233860380615079,
#             "longitude": 106.72662618864256
#           }
#         }
#       ]
#     },
#     {
#       "label": "101 L\u00fd Th\u01b0\u1eddng Ki\u1ec7t Street, Ward 3, M\u1ef9 Tho City, Ti\u1ec1n Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.035193865432031,
#             "longitude": 106.10986038617787
#           }
#         }
#       ]
#     },
#     {
#       "label": "2A L\u1ea1c Long Qu\u00e2n Street, Ninh Ki\u1ec1u Ward, Ninh Ki\u1ec1u District, C\u1ea7n Th\u01a1 City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 9.968998213804541,
#             "longitude": 106.03635960949444
#           }
#         }
#       ]
#     },
#     {
#       "label": "23 Tr\u1ea7n H\u01b0ng \u0110\u1ea1o Street, Ward 1, R\u1ea1ch Gi\u00e1 City, Ki\u00ean Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.417801043153785,
#             "longitude": 104.91013016364934
#           }
#         }
#       ]
#     },
#     {
#       "label": "14 \u0110i\u1ec7n Bi\u00ean Ph\u1ee7 Street, Ward 1, V\u1ecb Thanh City, H\u1eadu Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.47004914442764,
#             "longitude": 104.6631183363734
#           }
#         }
#       ]
#     },
#     {
#       "label": "7 Nguy\u1ec5n V\u0103n Tr\u1ed7i Street, Ward 5, Long Xuy\u00ean City, An Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.86180976238981,
#             "longitude": 105.26647295545288
#           }
#         }
#       ]
#     },
#     {
#       "label": "88 Nguy\u1ec5n Hu\u1ec7 Street, T\u00e2n Ph\u00fa Ward, \u0110\u1ed3ng Xo\u00e0i City, B\u00ecnh Ph\u01b0\u1edbc Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.82737636138809,
#             "longitude": 105.23869560143056
#           }
#         }
#       ]
#     },
#     {
#       "label": "15 H\u00f9ng V\u01b0\u01a1ng Street, Ward 2, B\u1ea1c Li\u00eau City, B\u1ea1c Li\u00eau Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.807509246133177,
#             "longitude": 105.34981715486578
#           }
#         }
#       ]
#     },
#     {
#       "label": "33 L\u00ea Du\u1ea9n Street, Ward 5, T\u00e2n An City, Long An Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.871983579869967,
#             "longitude": 105.46388175578417
#           }
#         }
#       ]
#     },
#     {
#       "label": "31 L\u00ea Du\u1ea9n Street, Ward 1, S\u00f3c Tr\u0103ng City, S\u00f3c Tr\u0103ng Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.896671511928368,
#             "longitude": 105.52822620598752
#           }
#         }
#       ]
#     },
#     {
#       "label": "100 Nguy\u1ec5n Th\u00e1i H\u1ecdc Street, T\u00e2n An Ward, Ninh Ki\u1ec1u District, C\u1ea7n Th\u01a1 City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.95203666271689,
#             "longitude": 105.69737678855225
#           }
#         }
#       ]
#     },
#     {
#       "label": "44 Nguy\u1ec5n T\u1ea5t Th\u00e0nh Street, Ph\u00fa Th\u1ee7y Ward, Phan Thi\u1ebft City, B\u00ecnh Thu\u1eadn Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.845343830513903,
#             "longitude": 105.84877506817693
#           }
#         }
#       ]
#     },
#     {
#       "label": "61 Phan B\u1ed9i Ch\u00e2u Street, Ward 3, R\u1ea1ch Gi\u00e1 City, Ki\u00ean Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.681360039330668,
#             "longitude": 106.04864823996134
#           }
#         }
#       ]
#     },
#     {
#       "label": "3 Tr\u01b0\u01a1ng C\u00f4ng \u0110\u1ecbnh Street, Ph\u01b0\u1eddng 1, V\u0129nh Long City, V\u0129nh Long Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.76951849138909,
#             "longitude": 106.63566909039788
#           }
#         }
#       ]
#     },
#     {
#       "label": "18 Nguy\u1ec5n Tr\u00e3i Street, Ward 2, T\u00e2n An City, Long An Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.7683131296682,
#             "longitude": 106.61993499921992
#           }
#         }
#       ]
#     },
#     {
#       "label": "73 Nguy\u1ec5n Tr\u00e3i Street, Ward 1, G\u00f2 C\u00f4ng Town, Ti\u1ec1n Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.774407237831625,
#             "longitude": 106.60399511375479
#           }
#         }
#       ]
#     },
#     {
#       "label": "27 \u0110\u01b0\u1eddng H\u00f9ng V\u01b0\u01a1ng, Th\u1ecb Tr\u1ea5n T\u00e2n Minh, H\u00e0m T\u00e2n District, B\u00ecnh Thu\u1eadn Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.805176744570572,
#             "longitude": 106.61418699054873
#           }
#         }
#       ]
#     },
#     {
#       "label": "17 L\u00ea Qu\u00fd \u0110\u00f4n Street, Ward 2, B\u00e0 R\u1ecba City, B\u00e0 R\u1ecba\u2013V\u0169ng T\u00e0u Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.8025536145907,
#             "longitude": 106.61534178616667
#           }
#         }
#       ]
#     },
#     {
#       "label": "9 Phan \u0110\u00ecnh Ph\u00f9ng Street, Th\u1ecb Tr\u1ea5n Long \u0110i\u1ec1n, Long \u0110i\u1ec1n District, B\u00e0 R\u1ecba\u2013V\u0169ng T\u00e0u Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.841844479419487,
#             "longitude": 106.63739329650186
#           }
#         }
#       ]
#     },
#     {
#       "label": "21 Tr\u1ea7n H\u01b0ng \u0110\u1ea1o Street, Ward 3, Sa \u0110\u00e9c City, \u0110\u1ed3ng Th\u00e1p Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.84786976455342,
#             "longitude": 106.63219671622107
#           }
#         }
#       ]
#     },
#     {
#       "label": "6 Qu\u1ed1c l\u1ed9 1A, B\u00ecnh Tr\u1ecb \u0110\u00f4ng B Ward, B\u00ecnh T\u00e2n District, Ho Chi Minh City, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.86238037056852,
#             "longitude": 106.67398339931346
#           }
#         }
#       ]
#     },
#     {
#       "label": "5 L\u00fd Th\u01b0\u1eddng Ki\u1ec7t Street, Ward 7, C\u00e0 Mau City, C\u00e0 Mau Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.856088860748844,
#             "longitude": 106.67834290755205
#           }
#         }
#       ]
#     },
#     {
#       "label": "52 Phan V\u0103n H\u1edbn Street, H\u00f2a Ph\u00fa Ward, Thu\u1eadn An City, B\u00ecnh D\u01b0\u01a1ng Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.877037498424992,
#             "longitude": 106.685048436705
#           }
#         }
#       ]
#     },
#     {
#       "label": "2A C\u00e1ch M\u1ea1ng Th\u00e1ng 8 Street, Ward 1, S\u00f3c Tr\u0103ng City, S\u00f3c Tr\u0103ng Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.883810943435149,
#             "longitude": 106.67276813088596
#           }
#         }
#       ]
#     },
#     {
#       "label": "11 Nguy\u1ec5n V\u0103n Linh Street, An H\u00f2a Ward, R\u1ea1ch Gi\u00e1 City, Ki\u00ean Giang Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.884614902931878,
#             "longitude": 106.66552275067981
#           }
#         }
#       ]
#     },
#     {
#       "label": "12 Tr\u01b0\u01a1ng \u0110\u1ecbnh Street, Ward 8, V\u0169ng T\u00e0u City, B\u00e0 R\u1ecba\u2013V\u0169ng T\u00e0u Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.885740442580465,
#             "longitude": 106.65578037473801
#           }
#         }
#       ]
#     },
#     {
#       "label": "5 V\u00f5 Th\u1ecb S\u00e1u Street, Ph\u01b0\u1edbc Hi\u1ec7p Ward, B\u00e0 R\u1ecba City, B\u00e0 R\u1ecba\u2013V\u0169ng T\u00e0u Province, Vietnam",
#       "deliveries": [
#         {
#           "arrival_location": {
#             "latitude": 10.889639600703328,
#             "longitude": 106.64978349156794
#           }
#         }
#       ]
#     }
#   ],
#   "vehicles": [
#     {
#       "label": "V1",
#       "start_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       },
#       "end_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       }
#     },
#     {
#       "label": "V2",
#       "start_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       },
#       "end_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       }
#     },
#     {
#       "label": "V3",
#       "start_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       },
#       "end_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       }
#     },
#     {
#       "label": "V4",
#       "start_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       },
#       "end_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       }
#     },
#     {
#       "label": "V5",
#       "start_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       },
#       "end_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       }
#     },
#     {
#       "label": "V6",
#       "start_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       },
#       "end_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       }
#     },
#     {
#       "label": "V7",
#       "start_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       },
#       "end_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       }
#     },
#     {
#       "label": "V8",
#       "start_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       },
#       "end_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       }
#     },
#     {
#       "label": "V9",
#       "start_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       },
#       "end_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       }
#     },
#     {
#       "label": "V10",
#       "start_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       },
#       "end_location": {
#         "latitude": 10.2509284,
#         "longitude": 105.978708
#       }
#     }
#   ],
#   "global_start_time": "2025-10-28T01:00:00Z",
#   "global_end_time": "2025-10-28T15:00:00Z"
# }

# %%
client = ro.RouteOptimizationClient()
req = ro.OptimizeToursRequest(
    parent=f"projects/{PROJECT}",
    model=model,
    consider_road_traffic=False,
    populate_polylines=False
)
print("Calling OptimizeTours...")
resp = client.optimize_tours(request=req)
print("Response received.")
print("Number of routes returned:", len(resp.routes))
# Out:
# /Users/huynhtai/Desktop/4. projects/VHoang/env/lib/python3.13/site-packages/google/auth/_default.py:108: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Calling OptimizeTours...
# Response received.
# Number of routes returned: 10

# %%
depot = (DEPOT_LAT, DEPOT_LNG)

summary_rows = []
for route in resp.routes:
    vlabel = route.vehicle_label
    ordered_labels = [v.shipment_label for v in route.visits if v.shipment_label]
    waypoints = [label_to_ll[lbl] for lbl in ordered_labels if lbl in label_to_ll]
    url = gmaps_url(origin=depot, waypoints=waypoints, destination=depot)

    print(f"\nVehicle {vlabel}:")
    print("  Stops:", " -> ".join(ordered_labels) if ordered_labels else "(no stops)")
    print("  Maps:", url)

    summary_rows.append({
        "vehicle": vlabel,
        "stops_count": len(ordered_labels),
        "stops_order": " -> ".join(ordered_labels),
        "maps_url": url
    })

summary_df = pd.DataFrame(summary_rows).sort_values(["vehicle"]).reset_index(drop=True)
summary_df
# Out:
# Vehicle V1:
#   Stops: 27 Đường Hùng Vương, Thị Trấn Tân Minh, Hàm Tân District, Bình Thuận Province, Vietnam -> 17 Lê Quý Đôn Street, Ward 2, Bà Rịa City, Bà Rịa–Vũng Tàu Province, Vietnam -> 9 Phan Đình Phùng Street, Thị Trấn Long Điền, Long Điền District, Bà Rịa–Vũng Tàu Province, Vietnam -> 21 Trần Hưng Đạo Street, Ward 3, Sa Đéc City, Đồng Tháp Province
Xoài City, Bình Phước Province, Vietnam -> 7 Nguyễn Văn Trỗi Street, Ward 5, Long Xuyên City, An Giang Province, Vietnam -> 15 Hùng Vương Street, Ward 2, Bạc Liêu City, Bạc Liêu Province, Vietnam -> 33 Lê Duẩn Street, Ward 5, Tân An City, Long An Province, Vietnam -> 31 Lê Duẩn Street, Ward 1, Sóc Trăng City, Sóc Trăng Province, Vietnam -> 100 Nguyễn Thái Học Street, Tân An Ward, Ninh Kiều District, Cần Thơ City, Vietnam -> 44 Nguyễn Tất Thành Street, Phú Thủy Ward, Phan Thiết City, Bình Thuận Province, Vietnam -> 61 Phan Bội Châu Street, Ward 3, Rạch Giá City, Kiên Giang Province, Vietnam
#   Maps: https://www.google.com/maps/dir/?api=1&origin=10.2509284,105.978708&destination=10.2509284,105.978708&waypoints=10.24814972360808,105.9391854507987|10.247025916127395,105.93858474386575|10.246310335473204,105.93858434280287|10.347062527288568,105.49148062625179|10.357721984471517,105.5140131222994|10.455934299048067,105.34307392794999|10.463966714458348,104.93084288031928|10.417801043153785,104.91013016364934|10.47004914442764,104.6631183363734|10.82737636138809,105.23869560143056|10.86180976238981,105.26647295545288|10.807509246133177,105.34981715486578|10.871983579869967,105.46388175578417|10.896671511928368,105.52822620598752|10.95203666271689,105.69737678855225|10.845343830513903,105.84877506817693|10.681360039330668,106.04864823996134
#
# Vehicle V10:
#   Stops: (no stops)
#   Maps: https://www.google.com/maps/dir/?api=1&origin=10.2509284,105.978708&destination=10.2509284,105.978708
#   vehicle  stops_count                                        stops_order  \
# 0      V1           25  27 Đường Hùng Vương, Thị Trấn Tân Minh, Hàm Tâ...
# 1     V10            0
# 2      V2           10  Hung Vuong I Residential Area, Phu Thuy Ward, ...
# 3      V3            6  Lot B, An Phú - An Khánh New Urban Area, An Ph...
# 4      V4           11  15 Trần Hưng Đạo Street, Ward 3, Vĩnh Long Cit...
# 5      V5           15  73 Nguyễn Trãi Street, Ward 1, Gò Công Town, T...
# 6      V6            0
# 7      V7           12  Nguyen Ai Quoc Street, Quang Vinh Ward, Bien H...
# 8      V8            0
# 9      V9           17  1231 Quốc lộ 1A, Bình Trị Đông B Ward, Bình Tâ...
#
#                                             maps_url
# 0  https://www.google.com/maps/dir/?api=1&origin=...
# 1  https://www.google.com/maps/dir/?api=1&origin=...
# 2  https://www.google.com/maps/dir/?api=1&origin=...
# 3  https://www.google.com/maps/dir/?api=1&origin=...
# 4  https://www.google.com/maps/dir/?api=1&origin=...
# 5  https://www.google.com/maps/dir/?api=1&origin=...
# 6  https://www.google.com/maps/dir/?api=1&origin=...
# 7  https://www.google.com/maps/dir/?api=1&origin=...
# 8  https://www.google.com/maps/dir/?api=1&origin=...
# 9  https://www.google.com/maps/dir/?api=1&origin=...

# %%
out_path = Path(env_str("ROUTES_CSV", "data/routes.csv"))
summary_df.to_csv(out_path, index=False)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/huynhtai/Desktop/4. projects/VHoang/project/data/routes.csv
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
